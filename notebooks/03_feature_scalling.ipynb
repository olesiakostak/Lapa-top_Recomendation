# %%
import pandas as pd

# %%
df = pd.read_csv('../data/laptop_featured.csv', index_col='Model')

# %%
df.head(1)
# Out:
#                                                     Price (₹)  Rating  Core  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...      50399    70.0     6
#
#                                                     Ram  Storage  Warranty  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...    8      512         1
#
#                                                     OS_Backlit Keyboard  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                    0
#
#                                                     OS_Chrome OS  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...             0
#
#                                                     OS_DOS 3.0 OS  OS_DOS OS  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...              0          0
#
#                                                     ...  \
# Model                                               ...
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...  ...
#
#                                                     Generation_Apple Silicon  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                         0
#
#                                                     Generation_Basic/Other  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                       0
#
#                                                     Generation_Tier 3  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                  0
#
#                                                     Generation_Tier 5  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                  1
#
#                                                     Generation_Tier 7  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                  0
#
#                                                     Generation_Tier 9  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                  0
#
#                                                     CPU_Brand_AMD  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...              1
#
#                                                     CPU_Brand_Apple  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                0
#
#                                                     CPU_Brand_Intel  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                0
#
#                                                     CPU_Brand_Other
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                0
#
# [1 rows x 36 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)
df_scaled.head(1)
# Out:
#                                                     Price (₹)    Rating  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...   0.082812  0.689655
#
#                                                         Core       Ram  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...  0.181818  0.096774
#
#                                                     Storage  Warranty  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...  0.11811  0.333333
#
#                                                     OS_Backlit Keyboard  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                  0.0
#
#                                                     OS_Chrome OS  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...           0.0
#
#                                                     OS_DOS 3.0 OS  OS_DOS OS  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...            0.0        0.0
#
#                                                     ...  \
# Model                                               ...
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...  ...
#
#                                                     Generation_Apple Silicon  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                       0.0
#
#                                                     Generation_Basic/Other  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                     0.0
#
#                                                     Generation_Tier 3  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                0.0
#
#                                                     Generation_Tier 5  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                1.0
#
#                                                     Generation_Tier 7  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                0.0
#
#                                                     Generation_Tier 9  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...                0.0
#
#                                                     CPU_Brand_AMD  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...            1.0
#
#                                                     CPU_Brand_Apple  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...              0.0
#
#                                                     CPU_Brand_Intel  \
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...              0.0
#
#                                                     CPU_Brand_Other
# Model
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...              0.0
#
# [1 rows x 36 columns]

# %%
df_scaled.to_csv('..\data\laptop_scaled.csv', index=True)
